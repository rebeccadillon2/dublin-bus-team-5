# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn import metrics

import joblib 
import os
import shutil

# %%
def get_split(df_line):

    # shuffle data frame code from 'sample_solution_COMP47350_Task2_PredictiveModeling_Evaluation_CreditRiskPrediction.ipynb'
    # randomly generate sequence based on dataframe index and set to be new index
    df_line.set_index(np.random.permutation(df_line.index))
    # sort the resulting random index
    df_line.sort_index(inplace=True)

    # drop unneeded columns
    df_line.drop(columns=['LINEID'], inplace=True)

    X = df_line.drop(columns=["TRIPTIME"], axis=1)
    y = pd.DataFrame(df_line['TRIPTIME'])

    # do test train split
    # Split the dataset into two datasets, 70% training and 30% test
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, random_state=1)

    return X_train, y_train, X_test, y_train

# %%
def train_test_dicts(df_dir):
    # create directory with all the lines of a direction
    lines_dir = sorted(list(df_dir['LINEID'].unique()))
    
    # Make dictionaries with keys for each line with each train/test split value as its values.
    X_train_dict = {}
    y_train_dict = {}
    X_test_dict = {}
    y_test_dict = {}

    for line in lines_dir:

        # dataframe containing only rows with current lineid
        df_line = df_dir[df_dir['LINEID'] == line]

        # check for df with low values (where accurate predictions will not be possible as any one value will have too much influence on the overall model outcome)
        if df_line.shape[0] < 3:
            print('Not enough values for line', str(line))
            lines_dir.remove(line)

        else:
            split = get_split(df_line)

            X_train_dict[line] = split[0]
            y_train_dict[line] = split[1]
            X_test_dict[line] = split[2]
            y_test_dict[line] = split[3]

    return lines_dir, X_train_dict, y_train_dict, X_test_dict, y_test_dict

# %%
def get_rfr_model_dict(direction, lines_dir, X_train_dict, y_train_dict, X_test_dict, y_test_dict):
    
    rf_model_dict = {}

    # figure out how to deal with no assigned value for x_train, y_train
    X_train = X_train_dict['1']
    y_train = y_train_dict['1']
    X_test = X_test_dict['1']
    y_test = y_test_dict['1']
    
    for line in lines_dir:
        print(f'Line {line}')

        X_train = X_train_dict[line]
        y_train = y_train_dict[line]
        X_test = X_test_dict[line]
        y_test = y_test_dict[line]
    
        rfr = RandomForestRegressor(oob_score=True, random_state=1, max_depth=20, n_estimators=20)
        result = rfr.fit(X_train, y_train)
        rf_model_dict[line] = result

        # code from https://stackoverflow.com/questions/11660605/how-to-overwrite-a-folder-if-it-already-exists-when-creating-it-with-makedirs

        dir = f'/Users/rebeccadillon/git/dublin-bus-team-5/machinelearning/data/modelling/randomforest/joblibfiles/line_{line}_model/dir{direction}'
        if os.path.exists(dir):
            shutil.rmtree(dir)
        os.makedirs(dir)

        # save the model to a joblib file
        filename = f'/Users/rebeccadillon/git/dublin-bus-team-5/machinelearning/data/modelling/randomforest/joblibfiles/line_{line}_model/dir{direction}/line_{line}_rfr.joblib'
        joblib.dump(result, open(filename, 'wb'))

    return rf_model_dict

# %%
def get_metric_lists(direction, lines_dir, rf_model_dict, X_train_dict, y_train_dict, X_test_dict, y_test_dict):
    # sum for averages
    train_mae_sum = 0
    train_mape_sum = 0
    train_mse_sum = 0
    train_r2_sum = 0

    test_mae_sum = 0
    test_mape_sum = 0
    test_mse_sum = 0
    test_r2_sum = 0

    train_metric_list = []
    test_metric_list = []

    for line in lines_dir:  

        # training data
        X_train = X_train_dict[line]
        y_train = y_train_dict[line]    
        # test data
        X_test = X_test_dict[line]
        y_test = y_test_dict[line]
        rfr = rf_model_dict[line]
                
        print('Now modelling for line', str(line))
        
        rfr_predictions_train = list(rfr.predict(X_train))
        rfr_predictions_test = list(rfr.predict(X_test))

        # choice of metrics from https://medium.com/analytics-vidhya/evaluating-a-random-forest-model-9d165595ad56 and
        # https://towardsdatascience.com/random-forest-regression-5f605132d19d
        train_mae = metrics.mean_absolute_error(y_train, rfr_predictions_train) 
        train_mape = metrics.mean_absolute_percentage_error(y_train, rfr_predictions_train) # should be as close to 0 as possible (percentage error)
        train_mse = metrics.mean_squared_error(y_train, rfr_predictions_train) # as close to 0 as possible
        train_r2 = metrics.r2_score(y_train, rfr_predictions_train) #close to 1
        
        test_mae = metrics.mean_absolute_error(y_test, rfr_predictions_test) 
        test_mape = metrics.mean_absolute_percentage_error(y_test, rfr_predictions_test) 
        test_mse = metrics.mean_squared_error(y_test, rfr_predictions_test)
        test_r2 = metrics.r2_score(y_test, rfr_predictions_test)


        with open(f'/Users/rebeccadillon/git/dublin-bus-team-5/machinelearning/data/modelling/randomforest/joblibfiles/line_{line}_model/dir{direction}/line_{line}_rfr_metrics.csv', 'w') as file:
            file.write(f'\nTrain metrics for line {line}:'
                    f'\nMAE: {train_mae}'+\
                    f'\nMAPE: {train_mape}'+\
                    f'\nMSE: {train_mse}'+\
                    f'\nR2: {train_r2}' +\
                    f'\nTest metrics for line {line}:'
                    f'\nMAE: {test_mae}'+\
                    f'\nMAPE: {test_mape}'+\
                    f'\nMSE: {test_mse}'+\
                    f'\nR2: {test_r2}')

        # sum for averages
        train_mae_sum +=train_mae
        train_mape_sum +=train_mape
        train_mse_sum +=train_mse
        train_r2_sum +=train_r2

        test_mae_sum += test_mae
        test_mape_sum += test_mape
        test_mse_sum += test_mse
        test_r2_sum += test_r2

    train_metric_list.append([train_mae_sum, train_mape_sum, train_mse_sum, train_r2_sum])
    test_metric_list.append([test_mae_sum, test_mape_sum, test_mse_sum, test_r2_sum])

    return train_metric_list, test_metric_list

# %%
def print_metrics(lines_dir, train_metric_list, test_metric_list):
    print("============Train metrics=============")
    print("Mean MAE:", str(train_metric_list[0]/len(lines_dir)))
    print("Mean MAPE:", str(train_metric_list[1]/len(lines_dir)))
    print("Mean MSE:", str(train_metric_list[2]/len(lines_dir)))
    print("Mean R2:", str(train_metric_list[3]/len(lines_dir)))

    print("============Test metrics=============")
    print("Mean MAE:", str(test_metric_list[0]/len(lines_dir)))
    print("Mean MAPE:", str(test_metric_list[1]/len(lines_dir)))
    print("Mean MSE:", str(test_metric_list[2]/len(lines_dir)))
    print("Mean R2:", str(test_metric_list[3]/len(lines_dir)))

# %%
df_dir_1 = pd.read_csv(
    '/Users/rebeccadillon/git/dublin-bus-team-5/machinelearning/data/modelling/modelling_ready_dir1.csv')

# %%
df_dir_1 = df_dir_1.drop(columns=['heavy_precip', 'weather_id', 'HOUR'])

# %% [markdown]
# **train_test_to_dict(df_dir_1)**
# * return lines_dir, X_train_dict, y_train_dict, X_test_dict, y_test_dict

# %%
return_func_1 = train_test_dicts(df_dir_1)
# Out:
# Not enough values for line 41D

# %%
lines_dir = return_func_1[0]
X_train_dict = return_func_1[1]
y_train_dict = return_func_1[2]
X_test_dict = return_func_1[3]
y_test_dict = return_func_1[4]

# %% [markdown]
# def rfr_model_creator(direction, lines_dir, X_train_dict, y_train_dict, X_test_dict, y_test_dict):
#     return rf_model_dict

# %%
X_train_dict
# Out:
# {'1':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  298545        63         4.1          62400.0        1     10
#  105874        93         6.7          44400.0        1      4
#  168956        73         3.1          60000.0        1      6
#  151230        63         7.2          73800.0        5      5
#  302971        82         3.1          66600.0        5     10
#  ...          ...         ...              ...      ...    ...
#  56371         60        10.8          46800.0        4      2
#  318040        76         6.7          62400.0        6     11
#  246687        59         6.7          47400.0        6      9
#  14435         93         3.6          50400.0        3      1
#  316121        93         2.1          76800.0        3     11
#
#  [4144 rows x 5 columns],
#  '102':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  40575         86         8.2          33600.0        0      2
#  294813        87         2.1          28200.0        5     10
#  322117        81         7.7          28200.0        3     11
#  248454        72         4.6          32700.0        0      9
#  276912        93         1.0          72600.0        4      9
#  ...          ...         ...              ...      ...    ...
#  294908        96         1.5          33600.0        5     10
#  103505        76         4.6          48300.0        0      4
#  124653        62         4.6          32700.0        5      4
#  29182         58        14.9          58500.0        1      1
#  121118        63         9.3          71100.0        2      4
#
#  [2154 rows x 5 columns],
#  '104':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  325483       100        4.60          36600.0        0     12
#  254352        63        4.10          51000.0        5      9
#  193228        68        3.60          58200.0        3      7
#  127386        84        4.10          28200.0        1      4
#  116457        62        8.80          51000.0        0      4
#  ...          ...         ...              ...      ...    ...
#  231425        45        5.70          61800.0        4      8
#  288433        77        2.10          65400.0        1     10
#  338055        86        2.24          72600.0        4     12
#  78420         46        3.10          47400.0        1      3
#  330248        75        8.80          51000.0        3     12
#
#  [789 rows x 5 columns],
#  '11':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  272485        78        4.60          48600.0        2      9
#  8425          93        9.30          34200.0        1      1
#  211218        87        6.70          34200.0        5      7
#  256165        75        5.66          70200.0        0      9
#  189769        56        6.70          55800.0        1      7
#  ...          ...         ...              ...      ...    ...
#  222347        68        3.10          63000.0        0      8
#  212913        76        2.10          84600.0        5      7
#  68424         75        5.10          61800.0        3      3
#  305617        76        7.70          46800.0        2     10
#  17413         86        2.10          41400.0        6      1
#
#  [3234 rows x 5 columns],
#  '111':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  144879        71         5.1          45000.0        2      5
#  26927         81         5.1          59400.0        0      1
#  155396        68         3.6          66600.0        5      6
#  279492        87         9.8          45000.0        1     10
#  190936        46         5.1          55800.0        2      7
#  ...          ...         ...              ...      ...    ...
#  163472        58        10.3          59400.0        5      6
#  203880        49         5.7          52200.0        2      7
#  251653        63         5.7          63000.0        1      9
#  52939         93         4.6          41400.0        0      2
#  238850        67         4.1          66600.0        5      8
#
#  [931 rows x 5 columns],
#  '114':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  240524        94         5.1          28200.0        0      8
#  306284        76         6.2          63000.0        2     10
#  167460        76         2.1          30600.0        1      6
#  173154        58         5.7          33300.0        3      6
#  145890        76         4.1          35400.0        3      5
#  ...          ...         ...              ...      ...    ...
#  180595        56         2.6          30600.0        1      6
#  218055        57         5.7          59700.0        4      8
#  269477        71         5.1          35400.0        1      9
#  67897         71         7.2          56400.0        3      3
#  260141        76         1.5          35400.0        3      9
#
#  [1061 rows x 5 columns],
#  '116':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  267423        54        4.12          55800.0        0      9
#  224380        59        4.10          55800.0        1      8
#  240956        67        9.80          55800.0        0      8
#  300409        72        2.60          55800.0        4     10
#  28960         66       13.40          55800.0        1      1
#  90946         66        9.30          55800.0        1      3
#  69940         86        5.70          55800.0        4      3
#  333219        76        5.70          55800.0        0     12
#  184729        34        4.10          55800.0        3      6
#  206435        50        5.70          55800.0        3      7
#  289640        77        6.70          55800.0        2     10
#  159278        55        3.10          55800.0        2      6
#  126836        82       10.30          55800.0        0      4
#  197895        56        4.10          55800.0        1      7
#  38678         87        5.10          55800.0        2      2
#  213992        43        4.10          55800.0        0      7
#  83135         71        6.20          55800.0        3      3
#  38885         87        5.10          55800.0        2      2
#  323074        81        5.70          55800.0        3     11
#  13197         93        3.60          55800.0        2      1
#  100627        71       10.30          55800.0        4      4
#  2881          80        3.60          55800.0        4      1
#  93331         87        6.70          55800.0        3      3
#  32360         75        4.60          55800.0        4      2
#  76535         62       10.30          55800.0        0      3
#  67941         71        7.20          55800.0        3      3
#  55016         70        5.70          55800.0        3      2
#  81256         66        9.30          55800.0        2      3
#  296563        67        4.10          55800.0        0     10,
#  '120':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  332438        93        12.9          42300.0        5     12
#  121036        59        10.3          66000.0        2      4
#  90351         87        10.3          40800.0        1      3
#  200850        82         3.6          32400.0        1      7
#  128213        93         3.1          45600.0        1      4
#  ...          ...         ...              ...      ...    ...
#  54861         75         5.7          54000.0        3      2
#  323072        81         5.7          56700.0        3     11
#  247299        59         6.7          64800.0        6      9
#  13311        100         3.1          61200.0        2      1
#  321185        76         6.2          61200.0        1     11
#
#  [3938 rows x 5 columns],
#  '122':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  141110        25        4.60          36900.0        5      5
#  193301        68        3.60          59640.0        3      7
#  124118        87        0.50          80100.0        4      4
#  55958         75        6.20          26100.0        4      2
#  345263        89        0.45          56100.0        3     12
#  ...          ...         ...              ...      ...    ...
#  50475         87        3.10          41400.0        6      2
#  293123        63        6.20          34800.0        4     10
#  223944        56        4.10          49200.0        1      8
#  12350        100        0.50          36000.0        2      1
#  291368        76        3.10          49200.0        3     10
#
#  [4426 rows x 5 columns],
#  '123':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  247711        67        5.10          79200.0        6      9
#  149820        77        7.70          36000.0        5      5
#  141961        48        6.20          78000.0        5      5
#  92391         60        5.70          54240.0        2      3
#  86913         89        3.10          30480.0        0      3
#  ...          ...         ...              ...      ...    ...
#  345252        89        0.45          54900.0        3     12
#  220684        68        3.10          40800.0        6      8
#  164451        93        4.60          36600.0        6      6
#  9845          93       12.40          59400.0        1      1
#  218726        73        4.10          36000.0        5      8
#
#  [5702 rows x 5 columns],
#  '13':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  32742         80         4.6          62220.0        4      2
#  103903        75         5.7          68400.0        0      4
#  155312        68         4.1          63900.0        5      6
#  73984         87         8.2          83700.0        1      3
#  77891         75         3.6          36600.0        1      3
#  ...          ...         ...              ...      ...    ...
#  230649        67         7.2          43800.0        4      8
#  220547        68         2.1          36000.0        6      8
#  75797         64         8.8          33000.0        0      3
#  319002        76         7.2          38400.0        0     11
#  19686         93         6.7          34800.0        0      1
#
#  [3112 rows x 5 columns],
#  '130':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  320741        71         5.1          43500.0        1     11
#  225314        67         2.6          76500.0        1      8
#  264538        86         5.1          30600.0        6      9
#  87282         61         4.1          36300.0        0      3
#  38138         86         5.1          43500.0        2      2
#  ...          ...         ...              ...      ...    ...
#  115797        62         7.2          36300.0        0      4
#  331462        75         6.7          29100.0        4     12
#  39057         87         5.1          54300.0        2      2
#  217160        88         6.2          72900.0        2      8
#  8909         100        10.8          39900.0        1      1
#
#  [5856 rows x 5 columns],
#  '14':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  94612         86        5.10          38400.0        4      3
#  98685         80        5.10          74400.0        5      3
#  5932          74        4.60          38400.0        0      1
#  266606        76        5.66          38400.0        0      9
#  215290        87        3.10          25200.0        2      8
#  ...          ...         ...              ...      ...    ...
#  52706        100        6.20          79800.0        6      2
#  301908        63        5.10          39600.0        5     10
#  229617        87        2.60          22500.0        4      8
#  14882        100        2.10          76800.0        3      1
#  300339        72        2.60          54900.0        4     10
#
#  [4445 rows x 5 columns],
#  '140':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  119392        76        5.70          32400.0        2      4
#  338229        86        2.68          82800.0        4     12
#  334946        79        0.89          63600.0        2     12
#  311597        71        4.10          42300.0        2     10
#  150457        63        7.20          49500.0        5      5
#  ...          ...         ...              ...      ...    ...
#  45647         65       12.90          49500.0        3      2
#  232412        87        5.10          42300.0        5      8
#  180344        93        1.00          23100.0        1      6
#  13021         93        3.60          53400.0        2      1
#  230706        63        6.70          49500.0        4      8
#
#  [5483 rows x 5 columns],
#  '142':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  192217        64         2.6          37800.0        3      7
#  59886         86         7.7          45000.0        2      2
#  205422        60         5.7          37800.0        3      7
#  222776        82         3.6          28500.0        1      8
#  143287        68         3.6          48600.0        0      5
#  ...          ...         ...              ...      ...    ...
#  304493        76         8.8          48600.0        1     10
#  330331        75         8.8          52200.0        3     12
#  32043         81         5.7          48600.0        4      2
#  99764         93         8.8          37800.0        4      4
#  19897         81         9.3          45000.0        0      1
#
#  [510 rows x 5 columns],
#  '145':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  222247        73         3.6          46800.0        0      8
#  259249        66         5.1          78000.0        2      9
#  280714        82         4.6          43200.0        2     10
#  209118        77         5.7          51600.0        4      7
#  319024        71         8.2          42600.0        0     11
#  ...          ...         ...              ...      ...    ...
#  93607         93         3.1          74400.0        3      3
#  272393        78         7.2          44400.0        2      9
#  28472         77        11.8          43200.0        1      1
#  173298        42         6.2          41400.0        3      6
#  8130          93        11.8          31200.0        1      1
#
#  [7170 rows x 5 columns],
#  '14C':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  342300        99         2.6          84600.0        6     12
#  237579        94         4.6          84600.0        2      8
#  182366        71         2.1          84600.0        1      6
#  200372        94         3.6          84600.0        0      7
#  332242        93        12.9          84600.0        4     12
#  ...          ...         ...              ...      ...    ...
#  311160        80         5.1          83400.0        5     10
#  55766         74         3.1          84600.0        3      2
#  304732        87         6.7          84600.0        1     10
#  64095         87         3.1          84600.0        1      3
#  188889        77         5.7          84600.0        0      7
#
#  [65 rows x 5 columns],
#  '15':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  142589        67        4.60          63600.0        6      5
#  352451        81        0.45          36000.0        0     12
#  234890       100        5.10          22200.0        0      8
#  156937        76        4.00          54000.0        1      6
#  160571        87        2.60          21600.0        4      6
#  ...          ...         ...              ...      ...    ...
#  110904        93        4.60          43200.0        3      4
#  295633        93        5.10          67200.0        5     10
#  33900         93        2.60          45600.0        6      2
#  194079        87        2.60          80400.0        3      7
#  8531          93        9.30          32760.0        1      1
#
#  [6653 rows x 5 columns],
#  '150':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  34153         76         3.6          57600.0        6      2
#  25238         81        13.9          82800.0        2      1
#  240230        72         5.1          77400.0        6      8
#  104577       100         7.7          28500.0        1      4
#  332490        93        10.8          48900.0        5     12
#  ...          ...         ...              ...      ...    ...
#  56608         64         8.8          51000.0        4      2
#  326798        93         5.1          82800.0        0     12
#  251831        77         5.1          72000.0        1      9
#  15117         75         7.2          34200.0        4      1
#  324950        93         4.6          82800.0        4     11
#
#  [3964 rows x 5 columns],
#  '151':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  72581         86        4.10          25800.0        1      3
#  208379        64        4.60          37200.0        4      7
#  17291         93        2.60          36000.0        6      1
#  144332        71        5.10          66000.0        1      5
#  273634        81        6.70          32400.0        3      9
#  ...          ...         ...              ...      ...    ...
#  61300         93        5.70          50400.0        6      3
#  348509        87        4.10          81000.0        4     12
#  267191        56        5.14          49200.0        0      9
#  17361         86        2.10          41400.0        6      1
#  346559        92        1.34          31800.0        4     12
#
#  [3698 rows x 5 columns],
#  '15A':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  309775        65         8.2          40200.0        5     10
#  136635        63         4.1          48600.0        6      5
#  105754        93         7.2          42600.0        1      4
#  10756         93        11.3          67500.0        1      1
#  210343        93         3.6          77400.0        4      7
#  ...          ...         ...              ...      ...    ...
#  58283         69         7.2          42600.0        1      2
#  332537        93         9.8          53400.0        5     12
#  255267        80         4.6          45000.0        0      9
#  14949         93         4.1          82800.0        3      1
#  330842        75         7.7          62100.0        3     12
#
#  [3931 rows x 5 columns],
#  '15B':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  89971         81        9.30          32400.0        1      3
#  126006        76        2.60          71100.0        5      4
#  103498        76        4.60          48000.0        0      4
#  105013        93        8.20          32400.0        1      4
#  348444        87        0.89          78000.0        4     12
#  ...          ...         ...              ...      ...    ...
#  59221         86        8.20          80100.0        1      2
#  329324        70        9.80          31200.0        3     12
#  259151        71        4.60          74700.0        2      9
#  13203         93        3.60          56400.0        2      1
#  327236        87        6.70          30180.0        3     12
#
#  [4022 rows x 5 columns],
#  '15D':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  270734        59         7.2          60180.0        1      9
#  231152        55         8.2          60180.0        4      8
#  261002        93         3.6          54000.0        3      9
#  274036        77         5.1          60180.0        3      9
#  226421        46         7.2          54000.0        2      8
#  ...          ...         ...              ...      ...    ...
#  203937        52         5.1          54000.0        2      7
#  331676        89         8.2          54000.0        4     12
#  226513        49         6.2          60180.0        2      8
#  206610        47         5.1          60180.0        3      7
#  107220        93         7.7          60180.0        1      4
#
#  [93 rows x 5 columns],
#  '16':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  50088         86         2.6          74400.0        5      2
#  257612        72        12.4          30000.0        2      9
#  282911        77         4.6          50400.0        3     10
#  206837        50         4.6          61800.0        3      7
#  196213        63         3.6          61200.0        6      7
#  ...          ...         ...              ...      ...    ...
#  41974         80         7.2          43200.0        1      2
#  231509        55         5.1          67800.0        4      8
#  174225        39         5.7          61800.0        3      6
#  12239         87         0.5          28800.0        2      1
#  229897        81         3.6          31200.0        4      8
#
#  [5526 rows x 5 columns],
#  '161':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  312683        93        4.10          54000.0        0     11
#  311801        71        3.60          54000.0        2     10
#  334701        79        1.34          54000.0        2     12
#  314072        75        2.10          36000.0        3     11
#  327456        93        6.70          36000.0        3     12
#  314506        75        2.60          39600.0        3     11
#  336748        94        0.89          36000.0        4     12
#  311569        71        4.10          39600.0        2     10
#  329519        65       11.30          36000.0        3     12
#  311510        71        2.60          36000.0        2     10
#  327574        93        5.70          39600.0        3     12
#  337170        96        0.45          39600.0        4     12
#  336854        94        0.89          36000.0        4     12
#  315413        87        2.10          60000.0        3     11
#  315191        81        2.60          54000.0        3     11
#  325893        81        5.70          54000.0        0     12
#  319462        76        4.60          60000.0        0     11
#  313100        87        8.80          36000.0        1     11,
#  '16C':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  225568        72         2.6          84600.0        1      8
#  222030        82         3.1          84600.0        6      8
#  77277         75         3.6          84600.0        0      3
#  54240         81         3.6          28200.0        3      2
#  317052        81         5.7          84600.0        4     11
#  ...          ...         ...              ...      ...    ...
#  204761        82         3.6          25200.0        3      7
#  55765         74         3.1          84600.0        3      2
#  332775        76         7.7          84600.0        5     12
#  188892        77         5.7          83400.0        0      7
#  27968         87         8.2          25200.0        1      1
#
#  [290 rows x 5 columns],
#  '16D':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  327112        87        6.20          27000.0        3     12
#  325271        93        3.60          30600.0        0     12
#  333871        75        1.79          29400.0        2     12
#  327160        87        6.20          25800.0        3     12
#  327245        87        6.70          31800.0        3     12
#  325153       100        4.10          27000.0        0     12
#  332863        86        3.10          30600.0        0     12
#  325057       100        4.10          25800.0        0     12
#  332864        86        3.10          31800.0        0     12
#  336599        95        2.60          31800.0        4     12
#  336598        95        2.60          30600.0        4     12
#  329177        66        8.80          27000.0        3     12
#  329176        66        8.80          28200.0        3     12
#  329352        70        9.80          31800.0        3     12
#  329332        70        9.80          29400.0        3     12
#  327113        87        6.20          28200.0        3     12,
#  '17':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  183400        68        3.10          26400.0        3      6
#  173223        51        7.20          36900.0        3      6
#  93531         81        4.60          65700.0        3      3
#  59371         63        9.80          25200.0        2      2
#  170935        77        7.70          32400.0        2      6
#  ...          ...         ...              ...      ...    ...
#  333420        85        3.58          76200.0        0     12
#  99172         87       10.30          27600.0        4      4
#  120135        72        9.80          53100.0        2      4
#  25583         81        8.20          28800.0        0      1
#  116587        62        9.30          57300.0        0      4
#
#  [2053 rows x 5 columns],
#  '17A':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  186074        29        5.70          39000.0        4      6
#  102923       100        1.50          84600.0        6      4
#  130136        76        9.80          33000.0        2      4
#  27563         81        6.20          77400.0        0      1
#  269391        71        5.10          35400.0        1      9
#  ...          ...         ...              ...      ...    ...
#  189373        63        5.10          39000.0        1      7
#  181920        50        4.60          66000.0        1      6
#  60832         87       10.80          67200.0        5      3
#  256158        75        5.66          70200.0        0      9
#  16421         87        8.20          46800.0        5      1
#
#  [3542 rows x 5 columns],
#  '18':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  69504         80         2.6          38700.0        4      3
#  270838        63         6.2          62400.0        1      9
#  17742         71         6.7          50700.0        6      1
#  282427        82         4.1          35400.0        3     10
#  319966        87         4.6          27300.0        1     11
#  ...          ...         ...              ...      ...    ...
#  326822        93         5.1          79800.0        0     12
#  108841        88         6.0          58500.0        2      4
#  131909        81         5.1          26100.0        4      4
#  29449         66         7.7          65100.0        1      1
#  126719        73         6.2          42300.0        0      4
#
#  [2083 rows x 5 columns],
#  '184':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  251435        67         5.7          54900.0        1      9
#  294372        82         5.7          65700.0        4     10
#  303262        82         3.6          75900.0        5     10
#  151551       100         2.1          23400.0        0      5
#  221112        53         4.6          50700.0        6      8
#  ...          ...         ...              ...      ...    ...
#  290642        82         5.7          28800.0        3     10
#  92304         57         6.7          49500.0        2      3
#  112273        93         4.1          65700.0        3      4
#  26035         87         7.2          36900.0        0      1
#  108669        89         8.0          49500.0        2      4
#
#  [2025 rows x 5 columns],
#  '185':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  235003        72         6.7          36600.0        0      8
#  208578        60         4.1          42300.0        4      7
#  234377        83         2.1          66600.0        6      8
#  91135         75         6.2          60000.0        1      3
#  246793        52         7.2          52200.0        6      9
#  ...          ...         ...              ...      ...    ...
#  125603        67         5.7          61200.0        5      4
#  119671        87         8.8          41400.0        2      4
#  141555        49         6.7          58800.0        5      5
#  31037         74         5.7          72300.0        3      2
#  138168        62         7.2          42300.0        2      5
#
#  [1622 rows x 5 columns],
#  '220':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  92974         81        5.70          34200.0        3      3
#  37691         92        5.10          34200.0        2      2
#  275154        81        3.60          34200.0        4      9
#  254650        88        1.54          24600.0        0      9
#  68194         66        5.70          61200.0        3      3
#  ...          ...         ...              ...      ...    ...
#  333942        75        1.79          28800.0        2     12
#  351408        84        0.89          62100.0        6     12
#  30757         75        9.30          45000.0        3      2
#  99904         93        9.80          39600.0        4      4
#  16299         93       10.30          39600.0        5      1
#
#  [542 rows x 5 columns],
#  '236':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  322334        81        7.70          28800.0        3     11
#  243926       100        3.10          32400.0        3      9
#  197111        93        2.60          25200.0        1      7
#  254921        77        4.12          28800.0        0      9
#  20715         87       11.30          28800.0        1      1
#  ...          ...         ...              ...      ...    ...
#  304990        87        8.80          25200.0        2     10
#  204766        82        3.60          25200.0        3      7
#  109861        93        5.10          28800.0        3      4
#  207634       100        5.10          25200.0        4      7
#  54218         81        3.60          25200.0        3      2
#
#  [156 rows x 5 columns],
#  '238':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  19367         93         7.2          24600.0        0      1
#  85254         55         3.1          45900.0        5      3
#  322236        81         7.7          31500.0        3     11
#  163505        58        10.3          60300.0        5      6
#  66207         93         5.1          24600.0        3      3
#  ...          ...         ...              ...      ...    ...
#  152568        72         6.2          49500.0        1      5
#  192994        68         3.1          56700.0        3      7
#  232329        72         5.1          38700.0        5      8
#  51778        100         6.2          64500.0        6      2
#  223850        67         5.1          45900.0        1      8
#
#  [1150 rows x 5 columns],
#  '239':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  204798        82        3.60          23400.0        3      7
#  353131        74        1.34          48600.0        0     12
#  308968        70        6.70          63000.0        4     10
#  105849        93        6.70          45000.0        1      4
#  132945        66        4.60          59400.0        4      4
#  ...          ...         ...              ...      ...    ...
#  324711        93        2.57          77400.0        5     11
#  293614        87        1.50          48600.0        4     10
#  251167        67        5.10          45000.0        1      9
#  308148        87        7.20          70200.0        3     10
#  82894         66        9.30          48600.0        3      3
#
#  [739 rows x 5 columns],
#  '25':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  123888        83         2.0          73800.0        4      4
#  296321        67         3.6          40800.0        0     10
#  124703        62         4.6          32700.0        5      4
#  109195        93         5.1          70200.0        2      4
#  72800         70         3.6          37200.0        1      3
#  ...          ...         ...              ...      ...    ...
#  155414        68         3.6          65100.0        5      6
#  198082        64         4.6          62400.0        1      7
#  232878        93         3.6          61500.0        5      8
#  53898         75         4.1          66600.0        2      2
#  226477        49         6.2          58800.0        2      8
#
#  [1165 rows x 5 columns],
#  '25A':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  29833         66       11.80          82920.0        1      1
#  16233         93       11.80          36120.0        5      1
#  226921        71        3.60          82920.0        2      8
#  201742        46        4.10          51420.0        1      7
#  335047        79        0.89          63720.0        2     12
#  ...          ...         ...              ...      ...    ...
#  204981        77        5.10          28020.0        3      7
#  195465        77        1.00          79320.0        4      7
#  65761         70        4.10          64920.0        2      3
#  282230        87        2.10          26820.0        3     10
#  19039         87        9.30          79320.0        6      1
#
#  [3546 rows x 5 columns],
#  '25B':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  105088        93         8.2          32520.0        1      4
#  13156         93         3.6          57120.0        2      1
#  189756        52         6.7          53820.0        1      7
#  116843        67         9.3          60420.0        0      4
#  234631        94         2.1          78420.0        6      8
#  ...          ...         ...              ...      ...    ...
#  231335        45         5.7          62820.0        4      8
#  222019        88         3.6          82020.0        6      8
#  75850         64         8.8          32520.0        0      3
#  313835        80         3.6          25920.0        3     11
#  17892         71         8.2          55020.0        6      1
#
#  [3194 rows x 5 columns],
#  '25D':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  111991        93         4.6          62700.0        3      4
#  198094        64         4.6          62700.0        1      7
#  200247        54         4.1          63900.0        0      7
#  308960        70         6.7          62700.0        4     10
#  112190        93         4.1          65100.0        3      4
#  ...          ...         ...              ...      ...    ...
#  189985        43         5.7          61500.0        1      7
#  91223         70         9.3          61500.0        1      3
#  191033        53         5.1          63900.0        2      7
#  316928        93         9.8          61500.0        4     11
#  44154         61         6.7          63900.0        2      2
#
#  [177 rows x 5 columns],
#  '25X':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  129059        82         4.1          59400.0        1      4
#  159293        51         4.1          59400.0        2      6
#  284663        54         4.1          59400.0        4     10
#  30301         81         7.7          63000.0        3      1
#  249535        85         5.7          59400.0        0      9
#  ...          ...         ...              ...      ...    ...
#  30237         76        10.3          59400.0        3      1
#  186413        32         4.6          59400.0        4      6
#  35713         69         2.1          63000.0        0      2
#  300757        74         2.1          63000.0        4     10
#  91047         75         6.2          59400.0        1      3
#
#  [88 rows x 5 columns],
#  '26':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  166618        82        5.10          54420.0        0      6
#  199115        73        1.50          43620.0        2      7
#  275651        62        4.60          43620.0        4      9
#  173225        51        7.20          36420.0        3      6
#  349767        89        0.89          59820.0        5     12
#  ...          ...         ...              ...      ...    ...
#  126329        50        2.60          81420.0        5      4
#  118390        59       12.40          56220.0        1      4
#  148028        59        8.20          34620.0        4      5
#  30837         70        7.70          56220.0        3      2
#  141229        43        4.10          45420.0        5      5
#
#  [1760 rows x 5 columns],
#  '27':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  283729        94         1.5          75600.0        3     10
#  125667        67         5.7          60600.0        5      4
#  333046        81         5.7          43200.0        0     12
#  282088        87         4.1          24000.0        3     10
#  83295         81         8.8          64200.0        3      3
#  ...          ...         ...              ...      ...    ...
#  39839         86         5.1          69000.0        2      2
#  246670        59         6.7          49200.0        6      9
#  184846        34         4.1          55800.0        3      6
#  9849          93        12.4          59400.0        1      1
#  242025        58         6.2          58800.0        2      8
#
#  [5538 rows x 5 columns],
#  '270':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  308262        87         5.0          72900.0        3     10
#  289358        72         8.2          44100.0        2     10
#  257717        68        11.8          33300.0        2      9
#  249573        85         5.7          58500.0        0      9
#  118229        63        13.9          47700.0        1      4
#  ...          ...         ...              ...      ...    ...
#  166673        77         6.7          58500.0        0      6
#  158694        55         4.6          44100.0        2      6
#  191731        82         4.1          29700.0        3      7
#  42932         64         4.1          83700.0        1      2
#  185228        36         4.1          62100.0        3      6
#
#  [1484 rows x 5 columns],
#  '27A':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  273735        72         7.7          40500.0        3      9
#  155538        82         4.1          73800.0        5      6
#  138916        86         3.6          81000.0        2      5
#  327481        93         6.7          38400.0        3     12
#  92376         60         5.7          56700.0        2      3
#  ...          ...         ...              ...      ...    ...
#  283076        77         4.6          60300.0        3     10
#  94620         86         5.1          38700.0        4      3
#  114741        76         5.7          67500.0        5      4
#  25500         81         8.2          26100.0        0      1
#  110637        93         4.6          42300.0        3      4
#
#  [2440 rows x 5 columns],
#  '27B':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  282383        82        4.10          32400.0        3     10
#  308469        93        7.70          27900.0        4     10
#  275213        81        3.60          34200.0        4      9
#  232365        72        5.10          36600.0        5      8
#  64404         81        6.20          29100.0        2      3
#  ...          ...         ...              ...      ...    ...
#  138838        70        4.10          73800.0        2      5
#  353347        76        0.45          56400.0        0     12
#  179445        58        3.60          24900.0        0      6
#  22695         93        9.30          78600.0        1      1
#  170317        88        8.80          24900.0        2      6
#
#  [2699 rows x 5 columns],
#  '27X':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  41157         65         7.7          61500.0        0      2
#  107257        93         7.2          63000.0        1      4
#  249617        88         5.7          63000.0        0      9
#  330788        75         8.2          61500.0        3     12
#  24475         87         7.7          61500.0        2      1
#  ...          ...         ...              ...      ...    ...
#  263626        71         6.2          63000.0        4      9
#  271053        63         6.2          63000.0        1      9
#  135816        47         4.1          63000.0        0      4
#  274156        93         6.7          63000.0        3      9
#  60477         64        11.3          63000.0        2      2
#
#  [116 rows x 5 columns],
#  '29A':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  115888        58        9.30          42000.0        0      4
#  316466        93        3.60          28800.0        4     11
#  347299        89        1.34          49200.0        4     12
#  243754        94        2.60          27000.0        3      9
#  140398        50        4.60          65700.0        3      5
#  ...          ...         ...              ...      ...    ...
#  209937        77        4.10          67500.0        4      7
#  199682        82        3.60          65700.0        2      7
#  64621         81        8.20          33600.0        2      3
#  282717        82        6.70          44400.0        3     10
#  17692         76        7.20          47400.0        6      1
#
#  [3465 rows x 5 columns],
#  '31':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  129593        84         7.2          75000.0        1      4
#  44239         61         6.7          64200.0        2      2
#  25984         87         7.2          39000.0        0      1
#  82023         75         7.7          77100.0        2      3
#  280639        88         3.6          37800.0        2     10
#  ...          ...         ...              ...      ...    ...
#  79771         69         3.6          78600.0        1      3
#  345907        85         1.0          71100.0        3     12
#  97663         70         7.2          48600.0        5      3
#  20510         87        10.8          84000.0        0      1
#  93956        100         3.1          26700.0        4      3
#
#  [2774 rows x 5 columns],
#  '31A':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  119707        87         8.8          40500.0        2      4
#  144428        81         3.6          73200.0        1      5
#  243410        77         4.6          73200.0        4      8
#  221315        53         3.6          61200.0        6      8
#  275507        66         4.6          40500.0        4      9
#  ...          ...         ...              ...      ...    ...
#  262542        93         7.2          33300.0        4      9
#  26420         81         6.2          47700.0        0      1
#  322413        76         8.8          33300.0        3     11
#  80957         68         8.8          47700.0        2      3
#  12829         86         3.1          47700.0        2      1
#
#  [697 rows x 5 columns],
#  '31B':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  149079        59        6.20          65400.0        4      5
#  73387         57        6.20          57900.0        1      3
#  116739        67        9.30          57900.0        0      4
#  198207        64        4.10          65400.0        1      7
#  249724        88        5.70          62400.0        0      9
#  ...          ...         ...              ...      ...    ...
#  181906        50        4.60          65400.0        1      6
#  336102        92        2.24          57900.0        3     12
#  88747         81        6.20          65400.0        0      3
#  308097        81        6.70          65400.0        3     10
#  48657         57        6.70          62400.0        4      2
#
#  [181 rows x 5 columns],
#  '31D':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  10597         93       11.30          62100.0        1      1
#  138587        58        5.70          62100.0        2      5
#  267853        52        3.09          62100.0        0      9
#  32604         80        4.60          62100.0        4      2
#  328324        87        3.10          62100.0        3     12
#  70130         93        6.20          62100.0        4      3
#  289788        82        5.10          62100.0        2     10
#  83406         81        8.80          62100.0        3      3
#  29357         66        9.80          62100.0        1      1
#  65650         65        5.10          62100.0        2      3
#  270943        63        6.20          62100.0        1      9
#  326303        87        2.60          62100.0        0     12
#  321360        67        4.60          62100.0        1     11
#  148945        49        9.30          62100.0        4      5
#  311966        71        2.10          62100.0        2     10
#  331903        93        8.80          62100.0        4     12
#  48639         57        6.70          62100.0        4      2
#  74795         93       13.90          62100.0        2      3
#  120689        72        8.80          62100.0        2      4
#  112121        93        4.60          62100.0        3      4
#  251583        63        5.70          62100.0        1      9
#  257024        56        6.20          62100.0        1      9
#  79067         39        3.10          62100.0        1      3
#  13392        100        3.10          62100.0        2      1
#  53865         70        4.60          62100.0        2      2
#  107319        93        7.20          62100.0        1      4
#  100928        62        8.80          62100.0        4      4
#  255856        71        6.17          62100.0        0      9
#  39320         87        4.60          62100.0        2      2
#  294251        77        6.70          62100.0        4     10
#  68227         75        5.10          62100.0        3      3
#  337784        83        1.79          62100.0        4     12
#  70234         93        6.20          62100.0        4      3
#  283236        77        4.10          62100.0        3     10
#  84288         57        1.00          62100.0        4      3
#  20207         86        9.80          62100.0        0      1
#  261269        93        4.10          62100.0        3      9
#  27151         81        3.60          62100.0        0      1
#  334961        79        0.89          62100.0        2     12
#  6908          78        6.70          62100.0        0      1
#  62809         93        2.60          62100.0        0      3
#  3095          80        3.60          62100.0        4      1
#  56891         65        8.20          62100.0        4      2
#  15640         81        6.20          62100.0        4      1
#  30940         75        9.80          62100.0        3      2
#  44203         61        6.70          62100.0        2      2
#  146978        72        2.60          62100.0        3      5,
#  '32':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  56912         70        7.70          65100.0        4      2
#  239479        83        4.60          48600.0        6      8
#  14928        100        3.60          81600.0        3      1
#  31080         75        6.20          81600.0        3      2
#  256086        75        5.66          70800.0        0      9
#  ...          ...         ...              ...      ...    ...
#  133358        70        2.60          74400.0        4      4
#  124471        62        3.60          29400.0        5      4
#  151655        84        3.60          33000.0        0      5
#  32787         75        5.10          65100.0        4      2
#  147073        72        2.60          66900.0        3      5
#
#  [1777 rows x 5 columns],
#  '32X':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  215482        82         3.6          27600.0        2      8
#  55965         75         6.2          26100.0        4      2
#  121752        87         4.6          26100.0        4      4
#  253673        87         5.1          27600.0        3      9
#  252170        93         3.6          26100.0        2      9
#  ...          ...         ...              ...      ...    ...
#  274706        93         3.6          26100.0        4      9
#  282264        87         2.1          26100.0        3     10
#  170484        82         8.8          26100.0        2      6
#  287515        72         9.8          26100.0        1     10
#  77517        100         4.1          26100.0        1      3
#
#  [114 rows x 5 columns],
#  '33':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  129596        84         7.2          73800.0        1      4
#  231212        55         8.2          59400.0        4      8
#  203036        77         3.1          22800.0        2      7
#  3746          80         8.2          22800.0        5      1
#  107545        97         6.7          66900.0        1      4
#  ...          ...         ...              ...      ...    ...
#  157812        82         4.6          25800.0        2      6
#  150519        63         5.7          52200.0        5      5
#  180193        55         3.6          73800.0        0      6
#  41425         80        10.3          79200.0        0      2
#  173638        42         6.2          48600.0        3      6
#
#  [1498 rows x 5 columns],
#  '33A':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  239169        88         5.1          45000.0        6      8
#  64917         66         9.8          46800.0        2      3
#  308648        81         9.3          39600.0        4     10
#  234390        83         2.1          65700.0        6      8
#  248898        67         5.1          43200.0        0      9
#  ...          ...         ...              ...      ...    ...
# ...
#  129078        76        6.20          61500.0        1      4
#  123572        62        4.60          61500.0        4      4
#  276439        66        3.10          61500.0        4      9
#  323281        81        4.10          61500.0        3     11
#  294092        77        6.70          61500.0        4     10
#  73618         57        5.70          61500.0        1      3
#  336162        92        1.79          61500.0        3     12
#  81658         66       10.30          61500.0        2      3
#  108992        90        6.00          61500.0        2      4
#  24456         87        7.70          61500.0        2      1
#  289807        82        5.10          61500.0        2     10
#  27108         81        3.60          61500.0        0      1
#  330743        75        8.20          61500.0        3     12
#  10310         93       11.30          61500.0        1      1
#  58933         59        6.70          61500.0        1      2
#  1522          81        7.20          61500.0        3      1
#  56866         65        8.20          61500.0        4      2
#  22303         93       10.30          61500.0        1      1
#  42581         60        7.70          61500.0        1      2
#  36705         69        6.20          61500.0        1      2
#  35682         69        2.10          61500.0        0      2
#  46273         69       10.30          61500.0        3      2
#  283234        77        4.10          61500.0        3     10
#  263591        71        6.20          61500.0        4      9,
#  '75':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  35298         80         3.1          41400.0        0      2
#  209114        77         5.7          52200.0        4      7
#  59457         63         9.8          27000.0        2      2
#  162578        77         5.7          34200.0        5      6
#  171298        63         4.6          45000.0        2      6
#  ...          ...         ...              ...      ...    ...
#  239566        82         7.2          52200.0        6      8
#  84575         93         2.1          82800.0        4      3
#  101004        62         5.7          64800.0        4      4
#  21789         93         9.3          52200.0        1      1
#  97526         75         8.2          45000.0        5      3
#
#  [2296 rows x 5 columns],
#  '76':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  173987        41        5.70          58800.0        3      6
#  124786        54        6.20          36000.0        5      4
#  179326        63        3.60          75600.0        6      6
#  353487        75        0.45          61200.0        0     12
#  12921         86        3.10          50400.0        2      1
#  ...          ...         ...              ...      ...    ...
#  334534        73        6.20          46800.0        2     12
#  98202         67        6.20          59400.0        5      3
#  345876        85        1.00          72000.0        3     12
#  20043         76       11.30          56400.0        0      1
#  95098         93        2.10          50400.0        4      3
#
#  [2862 rows x 5 columns],
#  '76A':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  130854        81         8.2          24000.0        3      4
#  104229        93         7.2          24000.0        1      4
#  200846        82         3.6          29400.0        1      7
#  214627        76         5.1          29400.0        1      7
#  75706         64         8.2          29400.0        0      3
#  ...          ...         ...              ...      ...    ...
#  242694        87         2.6          24000.0        4      8
#  249428        85         5.7          61200.0        0      9
#  137429        76         6.2          29400.0        2      5
#  252286        84         4.1          29400.0        2      9
#  74763         93        13.9          61200.0        2      3
#
#  [133 rows x 5 columns],
#  '77A':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  65016         57        9.30          49200.0        2      3
#  139513        57        5.10          39600.0        3      5
#  26247         81        9.30          44400.0        0      1
#  336324        83        0.45          82800.0        3     12
#  17789         71        6.70          51000.0        6      1
#  ...          ...         ...              ...      ...    ...
#  60147         63       10.30          51600.0        2      2
#  345219        86        1.34          52800.0        3     12
#  266744        64        5.66          42000.0        0      9
#  15711         87       11.30          70200.0        4      1
#  343083        85        2.10          52200.0        2     12
#
#  [3747 rows x 5 columns],
#  '79':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  18180         81         7.7          62640.0        6      1
#  71170        100         4.1          45360.0        6      3
#  154775        88         3.1          37500.0        5      6
#  92343         53         6.7          52200.0        2      3
#  207136        57         2.6          69600.0        3      7
#  ...          ...         ...              ...      ...    ...
#  341503        99         3.1          54000.0        6     12
#  97717         70         7.2          47400.0        5      3
#  350366        94         3.6          81000.0        5     12
#  20174         86         9.8          62400.0        0      1
#  95129         93         2.1          47100.0        4      3
#
#  [2833 rows x 5 columns],
#  '79A':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  319419        76         4.6          60300.0        0     11
#  330562        75         8.8          58800.0        3     12
#  226094        63         6.2          42900.0        2      8
#  265605        86         4.6          79200.0        6      9
#  75873         60         9.8          39300.0        0      3
#  ...          ...         ...              ...      ...    ...
#  299873        72         3.6          42900.0        4     10
#  98789         86         3.6          82200.0        5      3
#  120705        72         8.8          61800.0        2      4
#  26484         76         6.2          51600.0        0      1
#  117008        76         9.8          61800.0        0      4
#
#  [2284 rows x 5 columns],
#  '7A':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  97658         70         7.2          49500.0        5      3
#  125860        67         5.1          64800.0        5      4
#  148231        55         8.8          41400.0        4      5
#  173411        42         6.2          41400.0        3      6
#  42277         60         7.2          54000.0        1      2
#  ...          ...         ...              ...      ...    ...
#  302836        80         3.6          61200.0        5     10
#  98100         67         6.2          61200.0        5      3
#  118772        87         3.6          25200.0        2      4
#  25291         86         9.8          39600.0        4      1
#  114629        76         7.2          57600.0        5      4
#
#  [2301 rows x 5 columns],
#  '7B':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  35710         69         2.1          63600.0        0      2
#  32627         80         4.6          61800.0        4      2
#  206688        50         4.6          63600.0        3      7
#  160840        64         4.6          62400.0        4      6
#  253189        59         4.1          63600.0        2      9
#  ...          ...         ...              ...      ...    ...
#  198079        64         4.6          63000.0        1      7
#  258820        47         7.2          63600.0        2      9
#  70203         93         6.2          62400.0        4      3
#  228922        52         5.1          61800.0        3      8
#  30910         75         9.8          63600.0        3      2
#
#  [245 rows x 5 columns],
#  '7D':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  281502        77        3.60          63300.0        2     10
#  148967        49        9.30          63300.0        4      5
#  166711        77        7.20          63300.0        0      6
#  255841        71        6.17          63300.0        0      9
#  138684        58        5.70          63300.0        2      5
#  300680        74        2.10          63300.0        4     10
#  176228        51        4.10          63300.0        4      6
#  79109         39        3.10          63300.0        1      3
#  306205        76        6.20          63300.0        2     10
#  10552         93       11.30          63300.0        1      1
#  202199        46        3.10          63300.0        1      7
#  258821        47        7.20          63300.0        2      9
#  169314        61       10.80          63300.0        1      6
#  214192        72        2.60          63300.0        0      7
#  92548         53        5.70          63300.0        2      3
#  32571         80        4.60          63300.0        4      2
#  58962         59        6.70          63300.0        1      2
#  3132          80        3.60          63300.0        4      1
#  311929        71        2.10          63300.0        2     10
#  216808        77        7.20          63300.0        2      8
#  29300         66        9.80          63300.0        1      1
#  326313        87        2.60          63300.0        0     12
#  237109        88        4.10          63300.0        2      8
#  46145         69       10.30          63300.0        3      2
#  81558         66       10.30          63300.0        2      3
#  133107        57        3.60          63300.0        4      4
#  123365        62        4.60          63300.0        4      4
#  224682        59        3.60          63300.0        1      8
#  181851        46        5.10          63300.0        1      6
#  251575        63        5.70          63300.0        1      9
#  88701         71        6.20          63300.0        0      3
#  13467        100        3.10          63300.0        2      1
#  298458        63        4.10          63300.0        1     10
#  48789         57        6.70          63300.0        4      2
#  120703        72        8.80          63300.0        2      4
#  116989        76        9.80          63300.0        0      4
#  185141        36        4.10          63300.0        3      6
#  272934        78        3.60          63300.0        2      9
#  41191         65        7.70          63300.0        0      2
#  294185        77        6.70          63300.0        4     10
#  60491         64       11.30          63300.0        2      2
#  65599         65        5.10          63300.0        2      3
#  228807        52        5.10          63300.0        3      8
#  103864        76        6.70          63300.0        0      4
#  22367         93       10.30          63300.0        1      1
#  6809          78        6.70          63300.0        0      1
#  57751         55        7.20          63300.0        0      2
#  292109        71        3.10          63300.0        3     10
#  22219         93       10.30          63300.0        1      1
#  36712         69        6.20          63300.0        1      2
#  321398        67        4.60          63300.0        1     11
#  42613         60        7.70          63300.0        1      2
#  159641        55        3.60          63300.0        2      6,
#  '83':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  172403        62        5.70          76800.0        2      6
#  29124         58       14.90          60600.0        1      1
#  320413        76        4.10          37200.0        1     11
#  183250       100        2.10          20700.0        3      6
#  265562        86        4.10          74700.0        6      9
#  ...          ...         ...              ...      ...    ...
#  57279         69        6.70          21900.0        0      2
#  334362        73        7.20          43800.0        2     12
#  254831        86        1.54          28320.0        0      9
#  15149         75        7.20          35400.0        4      1
#  332663        86       18.50          70800.0        5     12
#
#  [3887 rows x 5 columns],
#  '83A':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  163618        59        9.30          62100.0        5      6
#  243065        59        6.70          48900.0        4      8
#  278506        60        8.80          63600.0        6      9
#  67964         71        7.20          56100.0        3      3
#  320244        87        4.10          34500.0        1     11
#  ...          ...         ...              ...      ...    ...
#  178048        59        6.20          59400.0        5      6
#  219340        59        4.60          52200.0        5      8
#  264997        66        9.80          52800.0        6      9
#  65889         81        3.60          74400.0        2      3
#  254986        76        5.66          34500.0        0      9
#
#  [1038 rows x 5 columns],
#  '84':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  204732        82         3.6          23400.0        3      7
#  203536        49         4.6          42000.0        2      7
#  153710        67         4.6          52800.0        2      5
#  34847        100         1.5          79800.0        6      2
#  84471         86         2.6          74400.0        4      3
#  ...          ...         ...              ...      ...    ...
#  167245        76         2.1          27000.0        1      6
#  329922        75        10.3          46800.0        3     12
#  202548        63         3.1          70800.0        1      7
#  41450         75        10.3          84600.0        0      2
#  196457        60         2.1          65400.0        6      7
#
#  [1352 rows x 5 columns],
#  '84A':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  322425        76         8.8          34200.0        3     11
#  260068        72         3.0          35400.0        3      9
#  300619        74         2.1          61800.0        4     10
#  280088        94         4.1          25200.0        2     10
#  55980         75         6.2          25200.0        4      2
#  ...          ...         ...              ...      ...    ...
#  66210         93         5.1          25200.0        3      3
#  72732         75         3.6          32400.0        1      3
#  40364         86         6.2          25200.0        0      2
#  127124        81         4.6          25200.0        1      4
#  20666         87        11.3          25200.0        1      1
#
#  [411 rows x 5 columns],
#  '84X':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  316867        93        11.3          60300.0        4     11
#  319539        81         5.1          61800.0        0     11
#  79200         39         3.1          63000.0        1      3
#  331787        93         7.7          60300.0        4     12
#  151825        68         4.6          60300.0        0      5
#  ...          ...         ...              ...      ...    ...
#  287217        72         7.2          60300.0        0     10
#  323255        81         4.1          64200.0        3     11
#  74873         93        12.4          66600.0        2      3
#  312523        93         4.6          43200.0        0     11
#  36700         69         6.2          64200.0        1      2
#
#  [203 rows x 5 columns],
#  '9':         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
#  2271          86         4.6          36000.0        4      1
#  147823        69         6.2          29400.0        4      5
#  171008        81         6.7          38700.0        2      6
#  109303       100         5.7          75600.0        2      4
#  190259        59         3.6          72000.0        1      7
#  ...          ...         ...              ...      ...    ...
#  45441         69        10.8          45000.0        3      2
#  259665        79         2.0          27900.0        3      9
#  196943        68         4.6          55500.0        0      7
#  11194         93         8.2          69600.0        1      1
#  257847        51        13.4          39600.0        2      9
#
#  [5076 rows x 5 columns]}

# %%
return_func_2 = get_rfr_model_dict(1,lines_dir, X_train_dict, y_train_dict, X_test_dict, y_test_dict)
# Out:
# Line 1
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 102
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 104
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 11
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 111
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 114
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 116
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 120
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 122
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 123
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 13
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 130
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 14
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 140
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 142
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 145
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 14C
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 15
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 150
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 151
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 15A
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 15B
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 15D
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 16
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 161
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 16C
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 16D
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 17
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 17A
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 18
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 184
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 185
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 220
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 236
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 238
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 239
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 25
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 25A
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 25B
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 25D
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 25X
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 26
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 27
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 270
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 27A
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 27B
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 27X
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 29A
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 31
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 31A
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 31B
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 31D
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 32
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 32X
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 33
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 33A
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 33B
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 33D
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 33E
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 33X
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 37
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 38
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# ...
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 69
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 69X
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 7
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 70
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 70D
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 75
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 76
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 76A
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 77A
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 79
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 79A
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 7A
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 7B
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 7D
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 83
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 83A
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 84
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 84A
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 84X
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]
# Line 9
#         humidity  wind_speed  PLANNEDTIME_DEP  WEEKDAY  MONTH
# 298545        63         4.1          62400.0        1     10
# 105874        93         6.7          44400.0        1      4
# 168956        73         3.1          60000.0        1      6
# 151230        63         7.2          73800.0        5      5
# 302971        82         3.1          66600.0        5     10
# ...          ...         ...              ...      ...    ...
# 56371         60        10.8          46800.0        4      2
# 318040        76         6.7          62400.0        6     11
# 246687        59         6.7          47400.0        6      9
# 14435         93         3.6          50400.0        3      1
# 316121        93         2.1          76800.0        3     11
#
# [4144 rows x 5 columns]

# %%
rf_model_dict = return_func_2

# %% [markdown]
# def metric_writer(direction, lines_dir, rf_model_dict, X_train_dict, y_train_dict, X_test_dict, y_test_dict):
#     return train_metric_list, test_metric_list

# %%
metric_list = get_metric_lists(1, lines_dir, rf_model_dict, X_train_dict, y_train_dict, X_test_dict, y_test_dict)
# Out:
# Now modelling for line 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [85], in <cell line: 1>()
# ----> 1 metric_list = get_metric_lists(1, lines_dir, rf_model_dict, X_train_dict, y_train_dict, X_test_dict, y_test_dict)
#
# Input In [76], in get_metric_lists(direction, lines_dir, rf_model_dict, X_train_dict, y_train_dict, X_test_dict, y_test_dict)
#      35 train_mse = metrics.mean_squared_error(y_train, rfr_predictions_train) # as close to 0 as possible
#      36 train_r2 = metrics.r2_score(y_train, rfr_predictions_train) #close to 1
# ---> 38 test_mae = metrics.mean_absolute_error(y_test, rfr_predictions_test)
#      39 test_mape = metrics.mean_absolute_percentage_error(y_test, rfr_predictions_test)
#      40 test_mse = metrics.mean_squared_error(y_test, rfr_predictions_test)
#
# File ~/opt/anaconda3/envs/rp22/lib/python3.8/site-packages/sklearn/metrics/_regression.py:196, in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     141 def mean_absolute_error(
#     142     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average"
#     143 ):
#     144     """Mean absolute error regression loss.
#     145
#     146     Read more in the :ref:`User Guide <mean_absolute_error>`.
#    (...)
#     194     0.85...
#     195     """
# --> 196     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     197         y_true, y_pred, multioutput
#     198     )
#     199     check_consistent_length(y_true, y_pred, sample_weight)
#     200     output_errors = np.average(np.abs(y_pred - y_true), weights=sample_weight, axis=0)
#
# File ~/opt/anaconda3/envs/rp22/lib/python3.8/site-packages/sklearn/metrics/_regression.py:100, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      66 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      67     """Check that y_true and y_pred belong to the same regression task.
#      68
#      69     Parameters
#    (...)
#      98         correct keyword.
#      99     """
# --> 100     check_consistent_length(y_true, y_pred)
#     101     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     102     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~/opt/anaconda3/envs/rp22/lib/python3.8/site-packages/sklearn/utils/validation.py:387, in check_consistent_length(*arrays)
#     385 uniques = np.unique(lengths)
#     386 if len(uniques) > 1:
# --> 387     raise ValueError(
#     388         "Found input variables with inconsistent numbers of samples: %r"
#     389         % [int(l) for l in lengths]
#     390     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [4144, 1777]

# %%
metric_list
# Out:
# ([[14246.313677435515,
#    5.218479330016565,
#    3663849.9744228986,
#    116.5086499510046]],
#  [[32252.297503796086,
#    12.089609267486242,
#    16781873.613603,
#    93.41447542545883]])

# %%
train_metric_list = metric_list[0][0]
test_metric_list = metric_list[1][0]

# %%
test_metric_list
# Out:
# [32252.297503796086, 12.089609267486242, 16781873.613603, 93.41447542545883]

# %%
print_metrics(lines_dir, train_metric_list, test_metric_list)
# Out:
# ============Train metrics=============
# Mean MAE: 115.82368843443508
# Mean MAPE: 0.04242666121964687
# Mean MSE: 29787.398166039828
# Mean R2: 0.9472247963496309
# ============Test metrics=============
# Mean MAE: 262.2138008438706
# Mean MAPE: 0.09828950623972554
# Mean MSE: 136437.99685856097
# Mean R2: 0.7594672798817791
