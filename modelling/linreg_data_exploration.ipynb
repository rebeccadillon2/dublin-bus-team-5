# %%
import pandas as pd
import numpy as np
import pickle
import seaborn as sns
import datetime as dt
from scipy import stats

from datetime import datetime, timedelta

from datetime import datetime
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches

from scipy.stats import norm, skew, boxcox
#For showing plots directly in the notebook run the command below
# %matplotlib inline

from patsy import dmatrices
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score 

from sklearn.decomposition import PCA, KernelPCA
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler

# For saving multiple plots into a single pdf file
from matplotlib.backends.backend_pdf import PdfPages
from sklearn.pipeline import Pipeline, make_pipeline
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(
    '/Users/rebeccadillon/git/dublin-bus-team-5/data/cleaned/cleaned_merged_weather_trips.csv')

# %%
df.shape
# Out:
# (713890, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 713890 entries, 0 to 713889
# Data columns (total 26 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   temp                 713890 non-null  float64
#  1   dew_point            713890 non-null  float64
#  2   feels_like           713890 non-null  float64
#  3   temp_min             713890 non-null  float64
#  4   temp_max             713890 non-null  float64
#  5   pressure             713890 non-null  int64
#  6   humidity             713890 non-null  int64
#  7   wind_speed           713890 non-null  float64
#  8   wind_deg             713890 non-null  int64
#  9   rain_1h              713890 non-null  float64
#  10  snow_1h              713890 non-null  float64
#  11  clouds_all           713890 non-null  int64
#  12  weather_id           713890 non-null  int64
#  13  weather_main         713890 non-null  object
#  14  weather_description  713890 non-null  object
#  15  snow_ice             713890 non-null  int64
#  16  heavy_precip         713890 non-null  int64
#  17  HOUR                 713890 non-null  int64
#  18  TRIPID               713890 non-null  int64
#  19  LINEID               713890 non-null  object
#  20  ROUTEID              713890 non-null  object
#  21  DIRECTION            713890 non-null  int64
#  22  TRIPTIME             713890 non-null  float64
#  23  WEEKDAY              713890 non-null  int64
#  24  MONTH                713890 non-null  int64
#  25  RUSHHOUR             713890 non-null  int64
# dtypes: float64(9), int64(13), object(4)
# memory usage: 141.6+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# temp                   0
# dew_point              0
# feels_like             0
# temp_min               0
# temp_max               0
# pressure               0
# humidity               0
# wind_speed             0
# wind_deg               0
# rain_1h                0
# snow_1h                0
# clouds_all             0
# weather_id             0
# weather_main           0
# weather_description    0
# snow_ice               0
# heavy_precip           0
# HOUR                   0
# TRIPID                 0
# LINEID                 0
# ROUTEID                0
# DIRECTION              0
# TRIPTIME               0
# WEEKDAY                0
# MONTH                  0
# RUSHHOUR               0
# dtype: int64

# %% [markdown]
# ## 1.2 On the training set we will now carry out a series of plots comparing all features to help make decisions on what features to keep for the model
#
# - All plots will be using the training subset of dataset: X_train, y_train
#
# ### 1.2.1 Plot the correlations between all the continuous features.

# %%
#split by direction first
df_dir_1 = df[df['DIRECTION']==1]
df_dir_2 = df[df['DIRECTION']==2]
directions_df_list = [df_dir_1, df_dir_2]

# %%
i=0
for direction in directions_df_list:
    i+=1
    print("Direction", str(i))
    # Analyse the histogram
    print('The skew of this distribution is = ', skew(direction['TRIPTIME']))
    sns.histplot(direction['TRIPTIME'], kde = True, color = 'blue')
    plt.show()
# Out:
# Direction 1
# The skew of this distribution is =  0.3047967566688049
# Direction 2
# The skew of this distribution is =  0.2511726875546783

# %% [markdown]
# The skew value above indicates that the data is positively skewed or skewed right. I will now check for outliers, first by creating a boxplot of the data.

# %% [markdown]
# ### change
# I will check for outliers by LINEID instead of by DIRECTION

# %% [markdown]
# #### Direction 1

# %%
dir_1_lines = list(df_dir_1['LINEID'].unique())

# %%
for line in dir_1_lines:
    # Analyse the histogram
    print("Line", str(line))
    sns.boxplot(x=df_dir_1['TRIPTIME'])
    plt.show()
# Out:
# Line 65
# Line 14
# Line 41C
# Line 39
# Line 140
# Line 123
# Line 38
# Line 27
# Line 69
# Line 83
# Line 44
# Line 15
# Line 25B
# Line 40
# Line 31
# Line 122
# Line 16
# Line 239
# Line 40D
# Line 42
# Line 15B
# Line 38B
# Line 120
# Line 145
# Line 66A
# Line 37
# Line 130
# Line 151
# Line 63
# Line 33
# Line 59
# Line 76
# Line 38D
# Line 238
# Line 29A
# Line 32
# Line 27A
# Line 7A
# Line 45A
# Line 185
# Line 41
# Line 15A
# Line 4
# Line 16C
# Line 49
# Line 142
# Line 84A
# Line 46A
# Line 7
# Line 54A
# Line 84
# Line 11
# Line 39A
# Line 26
# Line 75
# Line 76A
# Line 17A
# Line 47
# Line 79A
# Line 150
# Line 61
# Line 111
# Line 65B
# Line 79
# Line 68A
# Line 27B
# Line 56A
# Line 184
# Line 1
# Line 13
# Line 9
# Line 66
# Line 33B
# Line 18
# Line 53
# Line 270
# Line 25A
# Line 67
# Line 77A
# Line 84X
# Line 43
# Line 114
# Line 83A
# Line 17
# Line 102
# Line 104
# Line 68
# Line 38A
# Line 220
# Line 25
# Line 33X
# Line 66X
# Line 41X
# Line 67X
# Line 27X
# Line 40B
# Line 39X
# Line 31A
# Line 66B
# Line 236
# Line 44B
# Line 70
# Line 41B
# Line 15D
# Line 25X
# Line 31B
# Line 7D
# Line 25D
# Line 69X
# Line 33A
# Line 70D
# Line 7B
# Line 31D
# Line 32X
# Line 116
# Line 42D
# Line 51D
# Line 14C
# Line 33D
# Line 161
# Line 16D
# Line 40E
# Line 33E
# Line 41D

# %% [markdown]
# We can see from the above boxplot that there are some outliers lying between 15000 and 17500 seconds.

# %% [markdown]
# Code from https://stackoverflow.com/questions/68959573/how-do-i-delete-rows-in-a-dataframe-based-on-numpy-where

# %%
for line in dir_1_lines:
    # print number of rows in dataframe
    print("Number of rows remaining in dataframe:", str(df_dir_1.shape[0]))

    df_dir_1.reset_index(drop=True, inplace=True)
    print("Now doing line", str(line))

    # select all rows with the current line id 
    df_selected_line = df_dir_1.loc[df_dir_1['LINEID']==line]
    
    # get zscores
    line_zscores = np.abs(stats.zscore(df_selected_line['TRIPTIME']))
    
    # get rows above and below threshold
    rows_above_threshold = np.where(line_zscores > 3)
    rows_below_threshold = np.where(line_zscores < -3)
    # print number of rows
    print("There are", str(len(rows_above_threshold[0])), "row(s) above the threshold, and", str(len(rows_below_threshold[0])), "row(s) below \
         the threshold. ", str(len(rows_above_threshold[0])+len(rows_below_threshold[0])), "row(s) will be dropped from the dataframe")
    
    # convert to numpy array
    rows_above_threshold = np.asarray(rows_above_threshold)
    rows_below_threshold = np.asarray(rows_below_threshold)

    # drop rows outside of threshold
    df_dir_1 = df_dir_1.drop(rows_above_threshold.flatten(), axis=0)
    df_dir_1 = df_dir_1.drop(rows_below_threshold.flatten(), axis=0)
# Out:
# Number of rows remaining in dataframe: 357807
# Now doing line 65
# There are 15 row(s) above the threshold, and 0 row(s) below          the threshold.  15 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 357792
# Now doing line 14
# There are 49 row(s) above the threshold, and 0 row(s) below          the threshold.  49 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 357743
# Now doing line 41C
# There are 21 row(s) above the threshold, and 0 row(s) below          the threshold.  21 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 357722
# Now doing line 39
# There are 38 row(s) above the threshold, and 0 row(s) below          the threshold.  38 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 357684
# Now doing line 140
# There are 109 row(s) above the threshold, and 0 row(s) below          the threshold.  109 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 357575
# Now doing line 123
# There are 89 row(s) above the threshold, and 0 row(s) below          the threshold.  89 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 357486
# Now doing line 38
# There are 13 row(s) above the threshold, and 0 row(s) below          the threshold.  13 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 357473
# Now doing line 27
# There are 117 row(s) above the threshold, and 0 row(s) below          the threshold.  117 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 357356
# Now doing line 69
# There are 12 row(s) above the threshold, and 0 row(s) below          the threshold.  12 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 357344
# Now doing line 83
# There are 57 row(s) above the threshold, and 0 row(s) below          the threshold.  57 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 357287
# Now doing line 44
# There are 15 row(s) above the threshold, and 0 row(s) below          the threshold.  15 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 357272
# Now doing line 15
# There are 145 row(s) above the threshold, and 0 row(s) below          the threshold.  145 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 357127
# Now doing line 25B
# There are 33 row(s) above the threshold, and 0 row(s) below          the threshold.  33 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 357094
# Now doing line 40
# There are 308 row(s) above the threshold, and 0 row(s) below          the threshold.  308 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 356786
# Now doing line 31
# There are 29 row(s) above the threshold, and 0 row(s) below          the threshold.  29 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 356757
# Now doing line 122
# There are 134 row(s) above the threshold, and 0 row(s) below          the threshold.  134 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 356623
# Now doing line 16
# There are 21 row(s) above the threshold, and 0 row(s) below          the threshold.  21 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 356602
# Now doing line 239
# There are 6 row(s) above the threshold, and 0 row(s) below          the threshold.  6 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 356596
# Now doing line 40D
# There are 35 row(s) above the threshold, and 0 row(s) below          the threshold.  35 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 356561
# Now doing line 42
# There are 25 row(s) above the threshold, and 0 row(s) below          the threshold.  25 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 356536
# Now doing line 15B
# There are 20 row(s) above the threshold, and 0 row(s) below          the threshold.  20 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 356516
# Now doing line 38B
# There are 1 row(s) above the threshold, and 0 row(s) below          the threshold.  1 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 356515
# Now doing line 120
# There are 193 row(s) above the threshold, and 0 row(s) below          the threshold.  193 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 356322
# Now doing line 145
# There are 153 row(s) above the threshold, and 0 row(s) below          the threshold.  153 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 356169
# Now doing line 66A
# There are 7 row(s) above the threshold, and 0 row(s) below          the threshold.  7 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 356162
# Now doing line 37
# There are 38 row(s) above the threshold, and 0 row(s) below          the threshold.  38 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 356124
# Now doing line 130
# There are 52 row(s) above the threshold, and 0 row(s) below          the threshold.  52 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 356072
# Now doing line 151
# There are 28 row(s) above the threshold, and 0 row(s) below          the threshold.  28 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 356044
# Now doing line 63
# There are 13 row(s) above the threshold, and 0 row(s) below          the threshold.  13 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 356031
# Now doing line 33
# There are 27 row(s) above the threshold, and 0 row(s) below          the threshold.  27 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 356004
# Now doing line 59
# There are 5 row(s) above the threshold, and 0 row(s) below          the threshold.  5 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355999
# Now doing line 76
# There are 16 row(s) above the threshold, and 0 row(s) below          the threshold.  16 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355983
# Now doing line 38D
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355983
# Now doing line 238
# There are 11 row(s) above the threshold, and 0 row(s) below          the threshold.  11 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355972
# Now doing line 29A
# There are 16 row(s) above the threshold, and 0 row(s) below          the threshold.  16 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355956
# Now doing line 32
# There are 6 row(s) above the threshold, and 0 row(s) below          the threshold.  6 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355950
# Now doing line 27A
# There are 16 row(s) above the threshold, and 0 row(s) below          the threshold.  16 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355934
# Now doing line 7A
# There are 6 row(s) above the threshold, and 0 row(s) below          the threshold.  6 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355928
# Now doing line 45A
# There are 9 row(s) above the threshold, and 0 row(s) below          the threshold.  9 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355919
# Now doing line 185
# There are 1 row(s) above the threshold, and 0 row(s) below          the threshold.  1 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355918
# Now doing line 41
# There are 31 row(s) above the threshold, and 0 row(s) below          the threshold.  31 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355887
# Now doing line 15A
# There are 31 row(s) above the threshold, and 0 row(s) below          the threshold.  31 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355856
# Now doing line 4
# There are 185 row(s) above the threshold, and 0 row(s) below          the threshold.  185 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355671
# Now doing line 16C
# There are 1 row(s) above the threshold, and 0 row(s) below          the threshold.  1 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355670
# Now doing line 49
# There are 33 row(s) above the threshold, and 0 row(s) below          the threshold.  33 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355637
# Now doing line 142
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355637
# Now doing line 84A
# There are 10 row(s) above the threshold, and 0 row(s) below          the threshold.  10 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355627
# Now doing line 46A
# There are 154 row(s) above the threshold, and 0 row(s) below          the threshold.  154 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355473
# Now doing line 7
# There are 25 row(s) above the threshold, and 0 row(s) below          the threshold.  25 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355448
# Now doing line 54A
# There are 26 row(s) above the threshold, and 0 row(s) below          the threshold.  26 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355422
# Now doing line 84
# There are 31 row(s) above the threshold, and 0 row(s) below          the threshold.  31 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355391
# Now doing line 11
# There are 125 row(s) above the threshold, and 0 row(s) below          the threshold.  125 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355266
# Now doing line 39A
# There are 126 row(s) above the threshold, and 0 row(s) below          the threshold.  126 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355140
# Now doing line 26
# There are 34 row(s) above the threshold, and 0 row(s) below          the threshold.  34 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355106
# Now doing line 75
# There are 7 row(s) above the threshold, and 0 row(s) below          the threshold.  7 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355099
# Now doing line 76A
# There are 2 row(s) above the threshold, and 0 row(s) below          the threshold.  2 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355097
# Now doing line 17A
# There are 7 row(s) above the threshold, and 0 row(s) below          the threshold.  7 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355090
# Now doing line 47
# There are 19 row(s) above the threshold, and 0 row(s) below          the threshold.  19 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355071
# Now doing line 79A
# There are 28 row(s) above the threshold, and 0 row(s) below          the threshold.  28 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355043
# Now doing line 150
# There are 31 row(s) above the threshold, and 0 row(s) below          the threshold.  31 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355012
# Now doing line 61
# There are 17 row(s) above the threshold, and 0 row(s) below          the threshold.  17 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354995
# Now doing line 111
# There are 4 row(s) above the threshold, and 0 row(s) below          the threshold.  4 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354991
# Now doing line 65B
# There are 36 row(s) above the threshold, and 0 row(s) below          the threshold.  36 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354955
# Now doing line 79
# There are 41 row(s) above the threshold, and 0 row(s) below          the threshold.  41 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354914
# Now doing line 68A
# There are 5 row(s) above the threshold, and 0 row(s) below          the threshold.  5 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354909
# Now doing line 27B
# There are 25 row(s) above the threshold, and 0 row(s) below          the threshold.  25 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354884
# Now doing line 56A
# There are 15 row(s) above the threshold, and 0 row(s) below          the threshold.  15 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354869
# Now doing line 184
# There are 21 row(s) above the threshold, and 0 row(s) below          the threshold.  21 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354848
# Now doing line 1
# There are 4 row(s) above the threshold, and 0 row(s) below          the threshold.  4 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354844
# Now doing line 13
# There are 88 row(s) above the threshold, and 0 row(s) below          the threshold.  88 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354756
# Now doing line 9
# There are 117 row(s) above the threshold, and 0 row(s) below          the threshold.  117 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354639
# Now doing line 66
# There are 25 row(s) above the threshold, and 0 row(s) below          the threshold.  25 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354614
# Now doing line 33B
# There are 37 row(s) above the threshold, and 0 row(s) below          the threshold.  37 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354577
# Now doing line 18
# There are 18 row(s) above the threshold, and 0 row(s) below          the threshold.  18 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354559
# Now doing line 53
# There are 12 row(s) above the threshold, and 0 row(s) below          the threshold.  12 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354547
# Now doing line 270
# There are 6 row(s) above the threshold, and 0 row(s) below          the threshold.  6 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354541
# Now doing line 25A
# There are 29 row(s) above the threshold, and 0 row(s) below          the threshold.  29 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354512
# Now doing line 67
# There are 35 row(s) above the threshold, and 0 row(s) below          the threshold.  35 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354477
# Now doing line 77A
# There are 20 row(s) above the threshold, and 0 row(s) below          the threshold.  20 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354457
# Now doing line 84X
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354457
# Now doing line 43
# There are 15 row(s) above the threshold, and 0 row(s) below          the threshold.  15 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354442
# Now doing line 114
# There are 16 row(s) above the threshold, and 0 row(s) below          the threshold.  16 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354426
# Now doing line 83A
# There are 12 row(s) above the threshold, and 0 row(s) below          the threshold.  12 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354414
# Now doing line 17
# There are 59 row(s) above the threshold, and 0 row(s) below          the threshold.  59 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354355
# Now doing line 102
# There are 20 row(s) above the threshold, and 0 row(s) below          the threshold.  20 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354335
# Now doing line 104
# There are 16 row(s) above the threshold, and 0 row(s) below          the threshold.  16 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354319
# Now doing line 68
# There are 9 row(s) above the threshold, and 0 row(s) below          the threshold.  9 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354310
# Now doing line 38A
# There are 25 row(s) above the threshold, and 0 row(s) below          the threshold.  25 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354285
# Now doing line 220
# There are 5 row(s) above the threshold, and 0 row(s) below          the threshold.  5 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354280
# Now doing line 25
# There are 11 row(s) above the threshold, and 0 row(s) below          the threshold.  11 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354269
# Now doing line 33X
# There are 7 row(s) above the threshold, and 0 row(s) below          the threshold.  7 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354262
# Now doing line 66X
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354262
# Now doing line 41X
# There are 4 row(s) above the threshold, and 0 row(s) below          the threshold.  4 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354258
# Now doing line 67X
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354258
# Now doing line 27X
# There are 2 row(s) above the threshold, and 0 row(s) below          the threshold.  2 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354256
# Now doing line 40B
# There are 1 row(s) above the threshold, and 0 row(s) below          the threshold.  1 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354255
# Now doing line 39X
# There are 2 row(s) above the threshold, and 0 row(s) below          the threshold.  2 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354253
# Now doing line 31A
# There are 31 row(s) above the threshold, and 0 row(s) below          the threshold.  31 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354222
# Now doing line 66B
# There are 4 row(s) above the threshold, and 0 row(s) below          the threshold.  4 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354218
# Now doing line 236
# There are 5 row(s) above the threshold, and 0 row(s) below          the threshold.  5 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354213
# Now doing line 44B
# There are 9 row(s) above the threshold, and 0 row(s) below          the threshold.  9 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354204
# Now doing line 70
# There are 8 row(s) above the threshold, and 0 row(s) below          the threshold.  8 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354196
# Now doing line 41B
# There are 5 row(s) above the threshold, and 0 row(s) below          the threshold.  5 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354191
# Now doing line 15D
# There are 1 row(s) above the threshold, and 0 row(s) below          the threshold.  1 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354190
# Now doing line 25X
# There are 3 row(s) above the threshold, and 0 row(s) below          the threshold.  3 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354187
# Now doing line 31B
# There are 4 row(s) above the threshold, and 0 row(s) below          the threshold.  4 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354183
# Now doing line 7D
# There are 1 row(s) above the threshold, and 0 row(s) below          the threshold.  1 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354182
# Now doing line 25D
# There are 4 row(s) above the threshold, and 0 row(s) below          the threshold.  4 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354178
# Now doing line 69X
# There are 1 row(s) above the threshold, and 0 row(s) below          the threshold.  1 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354177
# Now doing line 33A
# There are 3 row(s) above the threshold, and 0 row(s) below          the threshold.  3 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354174
# Now doing line 70D
# There are 1 row(s) above the threshold, and 0 row(s) below          the threshold.  1 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354173
# Now doing line 7B
# There are 9 row(s) above the threshold, and 0 row(s) below          the threshold.  9 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354164
# Now doing line 31D
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354164
# Now doing line 32X
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354164
# Now doing line 116
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354164
# Now doing line 42D
# There are 2 row(s) above the threshold, and 0 row(s) below          the threshold.  2 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354162
# Now doing line 51D
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354162
# Now doing line 14C
# There are 1 row(s) above the threshold, and 0 row(s) below          the threshold.  1 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354161
# Now doing line 33D
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354161
# Now doing line 161
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354161
# Now doing line 16D
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354161
# Now doing line 40E
# There are 6 row(s) above the threshold, and 0 row(s) below          the threshold.  6 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354155
# Now doing line 33E
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354155
# Now doing line 41D
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe

# %% [markdown]
# I will now reindex the rows

# %%
df_dir_1.reset_index(drop=True, inplace=True)

# %% [markdown]
# Save to csv

# %%
df_dir_1.to_csv('/Users/rebeccadillon/git/dublin-bus-team-5/data/cleaned/linreg_exploration_dir_1_cleaned.csv', index=False)

# %% [markdown]
# ### Direction 2

# %%
dir_2_lines = list(df_dir_2['LINEID'].unique())

# %%
for line in dir_2_lines:
    # Analyse the histogram
    print("Line", str(line))
    sns.boxplot(x=df_dir_2['TRIPTIME'])
    plt.show()
# Out:
# Line 65
# Line 40
# Line 15B
# Line 7B
# Line 150
# Line 33
# Line 56A
# Line 33X
# Line 29A
# Line 18
# Line 49
# Line 83
# Line 70
# Line 184
# Line 4
# Line 15
# Line 41
# Line 46A
# Line 76A
# Line 44
# Line 11
# Line 77A
# Line 43
# Line 27
# Line 75
# Line 37
# Line 47
# Line 270
# Line 38B
# Line 14
# Line 53
# Line 130
# Line 140
# Line 27X
# Line 41X
# Line 70D
# Line 145
# Line 32
# Line 39A
# Line 41B
# Line 239
# Line 69X
# Line 84
# Line 41C
# Line 7A
# Line 66X
# Line 13
# Line 27A
# Line 65B
# Line 1
# Line 38
# Line 25B
# Line 7
# Line 122
# Line 42
# Line 123
# Line 84X
# Line 51X
# Line 67X
# Line 9
# Line 68
# Line 40D
# Line 46E
# Line 26
# Line 59
# Line 15D
# Line 16
# Line 33B
# Line 15A
# Line 76
# Line 17
# Line 220
# Line 45A
# Line 25X
# Line 17A
# Line 25A
# Line 66
# Line 83A
# Line 38A
# Line 67
# Line 31
# Line 102
# Line 185
# Line 39
# Line 84A
# Line 238
# Line 111
# Line 63
# Line 104
# Line 114
# Line 33A
# Line 120
# Line 142
# Line 27B
# Line 69
# Line 79
# Line 25
# Line 66A
# Line 151
# Line 54A
# Line 31A
# Line 79A
# Line 61
# Line 31B
# Line 66B
# Line 7D
# Line 41A
# Line 51D
# Line 118
# Line 39X
# Line 116
# Line 42D
# Line 68A
# Line 77X
# Line 44B
# Line 40B
# Line 16C
# Line 31D
# Line 25D
# Line 161
# Line 236
# Line 14C
# Line 32X
# Line 68X
# Line 38D
# Line 33D
# Line 40E
# Line 41D

# %%
for line in dir_2_lines:
    # print number of rows in dataframe
    print("Number of rows remaining in dataframe:", str(df_dir_2.shape[0]))

    df_dir_2.reset_index(drop=True, inplace=True)
    print("Now doing line", str(line))

    # select all rows with the current line id 
    df_selected_line = df_dir_2.loc[df_dir_2['LINEID']==line]
    
    # get zscores
    line_zscores = np.abs(stats.zscore(df_selected_line['TRIPTIME']))
    
    # get rows above and below threshold
    rows_above_threshold = np.where(line_zscores > 3)
    rows_below_threshold = np.where(line_zscores < -3)
    # print number of rows
    print("There are", str(len(rows_above_threshold[0])), "row(s) above the threshold, and", str(len(rows_below_threshold[0])), "row(s) below \
         the threshold. ", str(len(rows_above_threshold[0])+len(rows_below_threshold[0])), "row(s) will be dropped from the dataframe")
    
    # convert to numpy array
    rows_above_threshold = np.asarray(rows_above_threshold)
    rows_below_threshold = np.asarray(rows_below_threshold)

    # drop rows outside of threshold
    df_dir_2 = df_dir_2.drop(rows_above_threshold.flatten(), axis=0)
    df_dir_2 = df_dir_2.drop(rows_below_threshold.flatten(), axis=0)
# Out:
# Number of rows remaining in dataframe: 356083
# Now doing line 65
# There are 5 row(s) above the threshold, and 0 row(s) below          the threshold.  5 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 356078
# Now doing line 40
# There are 220 row(s) above the threshold, and 0 row(s) below          the threshold.  220 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355858
# Now doing line 15B
# There are 77 row(s) above the threshold, and 0 row(s) below          the threshold.  77 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355781
# Now doing line 7B
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355781
# Now doing line 150
# There are 52 row(s) above the threshold, and 0 row(s) below          the threshold.  52 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355729
# Now doing line 33
# There are 3 row(s) above the threshold, and 0 row(s) below          the threshold.  3 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355726
# Now doing line 56A
# There are 8 row(s) above the threshold, and 0 row(s) below          the threshold.  8 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355718
# Now doing line 33X
# There are 5 row(s) above the threshold, and 0 row(s) below          the threshold.  5 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355713
# Now doing line 29A
# There are 16 row(s) above the threshold, and 0 row(s) below          the threshold.  16 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355697
# Now doing line 18
# There are 20 row(s) above the threshold, and 0 row(s) below          the threshold.  20 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355677
# Now doing line 49
# There are 30 row(s) above the threshold, and 0 row(s) below          the threshold.  30 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355647
# Now doing line 83
# There are 95 row(s) above the threshold, and 0 row(s) below          the threshold.  95 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355552
# Now doing line 70
# There are 13 row(s) above the threshold, and 0 row(s) below          the threshold.  13 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355539
# Now doing line 184
# There are 28 row(s) above the threshold, and 0 row(s) below          the threshold.  28 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355511
# Now doing line 4
# There are 108 row(s) above the threshold, and 0 row(s) below          the threshold.  108 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355403
# Now doing line 15
# There are 152 row(s) above the threshold, and 0 row(s) below          the threshold.  152 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355251
# Now doing line 41
# There are 14 row(s) above the threshold, and 0 row(s) below          the threshold.  14 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355237
# Now doing line 46A
# There are 41 row(s) above the threshold, and 0 row(s) below          the threshold.  41 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355196
# Now doing line 76A
# There are 1 row(s) above the threshold, and 0 row(s) below          the threshold.  1 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355195
# Now doing line 44
# There are 62 row(s) above the threshold, and 0 row(s) below          the threshold.  62 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355133
# Now doing line 11
# There are 31 row(s) above the threshold, and 0 row(s) below          the threshold.  31 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355102
# Now doing line 77A
# There are 30 row(s) above the threshold, and 0 row(s) below          the threshold.  30 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355072
# Now doing line 43
# There are 19 row(s) above the threshold, and 0 row(s) below          the threshold.  19 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 355053
# Now doing line 27
# There are 129 row(s) above the threshold, and 0 row(s) below          the threshold.  129 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354924
# Now doing line 75
# There are 19 row(s) above the threshold, and 0 row(s) below          the threshold.  19 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354905
# Now doing line 37
# There are 32 row(s) above the threshold, and 0 row(s) below          the threshold.  32 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354873
# Now doing line 47
# There are 6 row(s) above the threshold, and 0 row(s) below          the threshold.  6 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354867
# Now doing line 270
# There are 12 row(s) above the threshold, and 0 row(s) below          the threshold.  12 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354855
# Now doing line 38B
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354855
# Now doing line 14
# There are 180 row(s) above the threshold, and 0 row(s) below          the threshold.  180 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354675
# Now doing line 53
# There are 21 row(s) above the threshold, and 0 row(s) below          the threshold.  21 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354654
# Now doing line 130
# There are 33 row(s) above the threshold, and 0 row(s) below          the threshold.  33 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354621
# Now doing line 140
# There are 117 row(s) above the threshold, and 0 row(s) below          the threshold.  117 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354504
# Now doing line 27X
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354504
# Now doing line 41X
# There are 2 row(s) above the threshold, and 0 row(s) below          the threshold.  2 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354502
# Now doing line 70D
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354502
# Now doing line 145
# There are 61 row(s) above the threshold, and 0 row(s) below          the threshold.  61 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354441
# Now doing line 32
# There are 9 row(s) above the threshold, and 0 row(s) below          the threshold.  9 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354432
# Now doing line 39A
# There are 179 row(s) above the threshold, and 0 row(s) below          the threshold.  179 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354253
# Now doing line 41B
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354253
# Now doing line 239
# There are 8 row(s) above the threshold, and 0 row(s) below          the threshold.  8 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354245
# Now doing line 69X
# There are 1 row(s) above the threshold, and 0 row(s) below          the threshold.  1 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354244
# Now doing line 84
# There are 2 row(s) above the threshold, and 0 row(s) below          the threshold.  2 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354242
# Now doing line 41C
# There are 5 row(s) above the threshold, and 0 row(s) below          the threshold.  5 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354237
# Now doing line 7A
# There are 3 row(s) above the threshold, and 0 row(s) below          the threshold.  3 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354234
# Now doing line 66X
# There are 5 row(s) above the threshold, and 0 row(s) below          the threshold.  5 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354229
# Now doing line 13
# There are 159 row(s) above the threshold, and 0 row(s) below          the threshold.  159 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354070
# Now doing line 27A
# There are 45 row(s) above the threshold, and 0 row(s) below          the threshold.  45 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 354025
# Now doing line 65B
# There are 26 row(s) above the threshold, and 0 row(s) below          the threshold.  26 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353999
# Now doing line 1
# There are 22 row(s) above the threshold, and 0 row(s) below          the threshold.  22 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353977
# Now doing line 38
# There are 2 row(s) above the threshold, and 0 row(s) below          the threshold.  2 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353975
# Now doing line 25B
# There are 31 row(s) above the threshold, and 0 row(s) below          the threshold.  31 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353944
# Now doing line 7
# There are 8 row(s) above the threshold, and 0 row(s) below          the threshold.  8 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353936
# Now doing line 122
# There are 103 row(s) above the threshold, and 0 row(s) below          the threshold.  103 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353833
# Now doing line 42
# There are 29 row(s) above the threshold, and 0 row(s) below          the threshold.  29 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353804
# Now doing line 123
# There are 63 row(s) above the threshold, and 0 row(s) below          the threshold.  63 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353741
# Now doing line 84X
# There are 4 row(s) above the threshold, and 0 row(s) below          the threshold.  4 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353737
# Now doing line 51X
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353737
# Now doing line 67X
# There are 7 row(s) above the threshold, and 0 row(s) below          the threshold.  7 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353730
# Now doing line 9
# There are 175 row(s) above the threshold, and 0 row(s) below          the threshold.  175 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353555
# Now doing line 68
# There are 4 row(s) above the threshold, and 0 row(s) below          the threshold.  4 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353551
# Now doing line 40D
# There are 16 row(s) above the threshold, and 0 row(s) below          the threshold.  16 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353535
# Now doing line 46E
# There are 1 row(s) above the threshold, and 0 row(s) below          the threshold.  1 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353534
# Now doing line 26
# There are 29 row(s) above the threshold, and 0 row(s) below          the threshold.  29 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353505
# Now doing line 59
# There are 18 row(s) above the threshold, and 0 row(s) below          the threshold.  18 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353487
# Now doing line 15D
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353487
# Now doing line 16
# There are 27 row(s) above the threshold, and 0 row(s) below          the threshold.  27 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353460
# Now doing line 33B
# There are 17 row(s) above the threshold, and 0 row(s) below          the threshold.  17 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353443
# Now doing line 15A
# There are 69 row(s) above the threshold, and 0 row(s) below          the threshold.  69 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353374
# Now doing line 76
# There are 20 row(s) above the threshold, and 0 row(s) below          the threshold.  20 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353354
# Now doing line 17
# There are 9 row(s) above the threshold, and 0 row(s) below          the threshold.  9 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353345
# Now doing line 220
# There are 4 row(s) above the threshold, and 0 row(s) below          the threshold.  4 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353341
# Now doing line 45A
# There are 4 row(s) above the threshold, and 0 row(s) below          the threshold.  4 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353337
# Now doing line 25X
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353337
# Now doing line 17A
# There are 15 row(s) above the threshold, and 0 row(s) below          the threshold.  15 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353322
# Now doing line 25A
# There are 53 row(s) above the threshold, and 0 row(s) below          the threshold.  53 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353269
# Now doing line 66
# There are 26 row(s) above the threshold, and 0 row(s) below          the threshold.  26 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353243
# Now doing line 83A
# There are 12 row(s) above the threshold, and 0 row(s) below          the threshold.  12 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353231
# Now doing line 38A
# There are 3 row(s) above the threshold, and 0 row(s) below          the threshold.  3 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353228
# Now doing line 67
# There are 16 row(s) above the threshold, and 0 row(s) below          the threshold.  16 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353212
# Now doing line 31
# There are 16 row(s) above the threshold, and 0 row(s) below          the threshold.  16 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353196
# Now doing line 102
# There are 28 row(s) above the threshold, and 0 row(s) below          the threshold.  28 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353168
# Now doing line 185
# There are 33 row(s) above the threshold, and 0 row(s) below          the threshold.  33 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353135
# Now doing line 39
# There are 6 row(s) above the threshold, and 0 row(s) below          the threshold.  6 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353129
# Now doing line 84A
# There are 7 row(s) above the threshold, and 0 row(s) below          the threshold.  7 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353122
# Now doing line 238
# There are 17 row(s) above the threshold, and 0 row(s) below          the threshold.  17 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353105
# Now doing line 111
# There are 80 row(s) above the threshold, and 0 row(s) below          the threshold.  80 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353025
# Now doing line 63
# There are 19 row(s) above the threshold, and 0 row(s) below          the threshold.  19 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 353006
# Now doing line 104
# There are 16 row(s) above the threshold, and 0 row(s) below          the threshold.  16 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352990
# Now doing line 114
# There are 19 row(s) above the threshold, and 0 row(s) below          the threshold.  19 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352971
# Now doing line 33A
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352971
# Now doing line 120
# There are 205 row(s) above the threshold, and 0 row(s) below          the threshold.  205 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352766
# Now doing line 142
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352766
# Now doing line 27B
# There are 42 row(s) above the threshold, and 0 row(s) below          the threshold.  42 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352724
# Now doing line 69
# There are 12 row(s) above the threshold, and 0 row(s) below          the threshold.  12 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352712
# Now doing line 79
# There are 32 row(s) above the threshold, and 0 row(s) below          the threshold.  32 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352680
# Now doing line 25
# There are 20 row(s) above the threshold, and 0 row(s) below          the threshold.  20 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352660
# Now doing line 66A
# There are 13 row(s) above the threshold, and 0 row(s) below          the threshold.  13 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352647
# Now doing line 151
# There are 25 row(s) above the threshold, and 0 row(s) below          the threshold.  25 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352622
# Now doing line 54A
# There are 24 row(s) above the threshold, and 0 row(s) below          the threshold.  24 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352598
# Now doing line 31A
# There are 11 row(s) above the threshold, and 0 row(s) below          the threshold.  11 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352587
# Now doing line 79A
# There are 22 row(s) above the threshold, and 0 row(s) below          the threshold.  22 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352565
# Now doing line 61
# There are 30 row(s) above the threshold, and 0 row(s) below          the threshold.  30 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352535
# Now doing line 31B
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352535
# Now doing line 66B
# There are 18 row(s) above the threshold, and 0 row(s) below          the threshold.  18 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352517
# Now doing line 7D
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352517
# Now doing line 41A
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352517
# Now doing line 51D
# There are 2 row(s) above the threshold, and 0 row(s) below          the threshold.  2 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352515
# Now doing line 118
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352515
# Now doing line 39X
# There are 3 row(s) above the threshold, and 0 row(s) below          the threshold.  3 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352512
# Now doing line 116
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352512
# Now doing line 42D
# There are 2 row(s) above the threshold, and 0 row(s) below          the threshold.  2 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352510
# Now doing line 68A
# There are 1 row(s) above the threshold, and 0 row(s) below          the threshold.  1 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352509
# Now doing line 77X
# There are 1 row(s) above the threshold, and 0 row(s) below          the threshold.  1 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352508
# Now doing line 44B
# There are 8 row(s) above the threshold, and 0 row(s) below          the threshold.  8 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352500
# Now doing line 40B
# There are 6 row(s) above the threshold, and 0 row(s) below          the threshold.  6 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352494
# Now doing line 16C
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352494
# Now doing line 31D
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352494
# Now doing line 25D
# There are 1 row(s) above the threshold, and 0 row(s) below          the threshold.  1 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352493
# Now doing line 161
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352493
# Now doing line 236
# There are 2 row(s) above the threshold, and 0 row(s) below          the threshold.  2 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352491
# Now doing line 14C
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352491
# Now doing line 32X
# There are 2 row(s) above the threshold, and 0 row(s) below          the threshold.  2 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352489
# Now doing line 68X
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352489
# Now doing line 38D
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352489
# Now doing line 33D
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352489
# Now doing line 40E
# There are 9 row(s) above the threshold, and 0 row(s) below          the threshold.  9 row(s) will be dropped from the dataframe
# Number of rows remaining in dataframe: 352480
# Now doing line 41D
# There are 0 row(s) above the threshold, and 0 row(s) below          the threshold.  0 row(s) will be dropped from the dataframe

# %%
df_dir_2.to_csv('/Users/rebeccadillon/git/dublin-bus-team-5/data/cleaned/linreg_exploration_dir_2_cleaned.csv', index=False)

# %% [markdown]
# # Move to feature_pairwise_interactions
# # Continue with data exploration
